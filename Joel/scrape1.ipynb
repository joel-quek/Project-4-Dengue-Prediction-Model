# %% [markdown]
# # Scrape 1
#
# http://www.weather.gov.sg/climate-historical-daily/

# %%
import requests

# %%
page = requests.get("http://www.weather.gov.sg/climate-historical-daily/")

# %%
print(type(page))
# Out:
# <class 'requests.models.Response'>

# %%
print(page.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="en-US">
# <![endif]-->
# <!--[if !(IE 7) & !(IE 8)]><!-->
# <html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="UTF-8" />
# <meta name="viewport" content="width=device-width" />
# <!--<meta http-equiv="cache-control" content="max-age=0" />
# <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate" />
# <meta http-equiv="expires" content="0" />
# <meta http-equiv="expires" content="Tue, 01 Jan 1980 1:00:00 GMT" />
# <meta http-equiv="pragma" content="no-cache" />
# -->
# <!-- <meta http-equiv="cache-control" content="public, max-age=60, must-revalidate" /> -->
# <title>Historical Daily Records | </title>
# <link rel="profile" href="http://gmpg.org/xfn/11" />
# <link rel="pingback" href="http://www.weather.gov.sg/xmlrpc.php" />
# ...

# %% [markdown]
# # BeautifulSoup

# %%
import bs4
from bs4 import BeautifulSoup

# %%
URL = "http://www.weather.gov.sg/climate-historical-daily/"

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup.extract()
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="en-US">
# <![endif]-->
# <!--[if !(IE 7) & !(IE 8)]><!-->
# <html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <!--<meta http-equiv="cache-control" content="max-age=0" />
# <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate" />
# <meta http-equiv="expires" content="0" />
# <meta http-equiv="expires" content="Tue, 01 Jan 1980 1:00:00 GMT" />
# <meta http-equiv="pragma" content="no-cache" />
# -->
# <!-- <meta http-equiv="cache-control" content="public, max-age=60, must-revalidate" /> -->
# <title>Historical Daily Records | </title>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="http://www.weather.gov.sg/xmlrpc.php" rel="pingback"/>
# ...

# %%
print(soup.title)
print(soup.title.text)
# Out:
# <title>Historical Daily Records | </title>
# Historical Daily Records |

# %% [markdown]
# # Download CSV Directly

# %%
import pandas as pd

# %%
URL = "http://www.weather.gov.sg/files/dailydata/DAILYDATA_S24_202210.csv"

# %% [markdown]
# ## Use Pandas

# %%
pd.read_csv(URL,allow_redirects=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\redoc\OneDrive\Desktop\DSI-Roughpaper\0. project_4\scrape1.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/redoc/OneDrive/Desktop/DSI-Roughpaper/0.%20project_4/scrape1.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> pd.read_csv(URL,allow_redirects=True)
#
# File c:\Users\redoc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: read_csv() got an unexpected keyword argument 'allow_redirects'

# %% [markdown]
# ## Use urllib and csv

# %%
import sys

# !{sys.executable} -m pip install urllib.request
# Out:
# ERROR: Could not find a version that satisfies the requirement urllib.request (from versions: none)
# ERROR: No matching distribution found for urllib.request

# %%
import urllib
import urllib.request

# from urllib import urlopen
import csv

# %%
res = urllib.requests.urlopen(URL)
data = csv.reader(res)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\redoc\OneDrive\Desktop\DSI-Roughpaper\0. project_4\scrape1.ipynb Cell 20 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/redoc/OneDrive/Desktop/DSI-Roughpaper/0.%20project_4/scrape1.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> res = urllib.requests.urlopen(URL)
#       <a href='vscode-notebook-cell:/c%3A/Users/redoc/OneDrive/Desktop/DSI-Roughpaper/0.%20project_4/scrape1.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> data = csv.reader(res)
#
# AttributeError: module 'urllib' has no attribute 'requests'

# %% [markdown]
# ## Use Requests and CSV

# %%
import requests
import csv
res = requests.get(URL)
t = res.iter_lines()
data = csv.reader(t, delimiter=',')

# %%
t
# Out:
# <generator object Response.iter_lines at 0x000002677ED1F760>

# %%
print(data)

# %%
res
# Out:
# <Response [200]>

# %% [markdown]
# # Try Again

# %% [markdown]
# https://www.folkstalk.com/2022/10/python-download-file-from-url-with-code-examples.html

# %%
r = requests.get(URL, allow_redirects=True)

# %%
r
# Out:
# <Response [200]>

# %%
df = pd.DataFrame(r)

# %%
df
# Out:
#                                                     0
# 0   b'Station,Year,Month,Day,Daily Rainfall Total ...
# 1   b'all (mm),Mean Temperature (\xb0C),Maximum Te...
# 2   b'hangi,2022,10,1,15,11.8,14.6,14.6,27.6,32.9,...
# 3   b'2,10,3,0.2,0.2,0.2,0.2,26.8,30,25.1,5.2,27.4...
# 4   b',26.8,29.4,23.8,5.4,21.3\r\nChangi,2022,10,6...
# 5   b'6.9,28.2\r\nChangi,2022,10,8,0.2,0.2,0.2,0.2...
# 6   b'10,10,7.6,6.4,6.6,7.6,26.9,28.9,23.7,4.4,35\...
# 7   b'2,2,26.9,30.4,24,7.2,30.2\r\nChangi,2022,10,...
# 8   b'.6,40.4\r\nChangi,2022,10,15,1.2,1.2,1.2,1.2...
# 9   b'\r\nChangi,2022,10,17,11,6.6,8.4,10.4,27.8,3...
# 10  b'1.6,2,2,28.7,31.4,26.4,7,26.7\r\nChangi,2022...
# 11  b'9.8,23.1,2.8,29.4\r\nChangi,2022,10,22,22,17...
# 12  b'1.7\r\nChangi,2022,10,24,1.6,0.6,0.8,1.2,27....
# 13  b'hangi,2022,10,26,0.2,0.2,0.2,0.2,26.7,29.7,2...
# 14  b'0,28,6,5.2,5.2,5.2,28.2,34.6,24.5,8.1,29.1\r...
# 15  b'.8,27.4,31.3,23.2,-,37.8\r\nChangi,2022,10,3...
